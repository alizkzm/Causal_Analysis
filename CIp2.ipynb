# %%
import numpy as np

size = 100000
v = np.random.standard_normal(size)
x = 2*v+np.random.standard_normal(size)
y = -x+np.random.standard_normal(size)
z = 2*x+np.random.standard_normal(size)
w = -2*v+3*y+5*z+np.random.standard_normal(size)
W = w[abs(x-3)<0.01]

plt.figure()
plt.hist2d(x,w)
plt.title("Joint Probability of X and W")
plt.xlabel("X")
plt.ylabel("W")
plt.show()

plt.figure()
plt.hist(W,density=True)
plt.title("Joint Probability of W|X=3")
plt.xlabel("W")
plt.show()

v = np.random.standard_normal(size)
x = 3
y = -x+np.random.standard_normal(size)
z = 2*x+np.random.standard_normal(size)
w = -2*v+3*y+5*z+np.random.standard_normal(size)

plt.figure()
plt.hist(w,density=True)
plt.title("Joint Probability of W (Do X:=3)")
plt.xlabel("W")
plt.show()
